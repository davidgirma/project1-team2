# %%
# Set dependencies and Setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read CSV file
rawdata = pd.read_csv('datasources/Producto-interno-bruto-anual.csv')

dict1 = {
    'Sector': rawdata['Sector'],
    'Year': rawdata['Year'],
    'GDP': rawdata['GDP']
}

df = pd.DataFrame(dict1)



df = df.set_index(['Year', 'Sector']).unstack()

ax = df.plot(linestyle='-', figsize=(10, 6))
# Customize y-axis labels to show values in trillions
formatter = plt.FuncFormatter(lambda x, _: f'{x / 1e12:.0f}T')
ax.yaxis.set_major_formatter(formatter)

# Adding labels and legend
plt.ylabel('Trillions of pesos')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
df.head()
# Out:
#                                                                                                                               GDP  \
# Sector Actividades legislativas, gubernamentales, de impartición de justicia y de organismos internacionales y extraterritoriales
# Year
# 1993                                          48618500000
# 1994                                          58430250000
# 1995                                          68887500000
# 1996                                          89482750000
# 1997                                         118030250000
#
#                                                                                             \
# Sector Agricultura, cría y explotación de animales, aprovechamiento forestal, pesca y caza
# Year
# 1993                                          79188250000
# 1994                                          81539250000
# 1995                                         100801500000
# 1996                                         150412500000
# 1997                                         174868750000
#
#                                                                   \
# Sector Comercio al por mayor Comercio al por menor  Construcción
# Year
# 1993            124107500000          142307000000   89880000000
# 1994            138646750000          154463750000  118033500000
# 1995            203685500000          219380750000  116553750000
# 1996            289556750000          308788500000  164629000000
# 1997            371437000000          370668250000  211514250000
#
#                                                                           \
# Sector Dirección y administración de grupos empresariales o corporativos
# Year
# 1993                                           5933250000
# 1994                                           8649000000
# 1995                                          11579500000
# 1996                                          15115250000
# 1997                                          20713000000
#
#                                                                                                                                                           \
# Sector Generación, transmisión, distribución y comercialización de energía eléctrica, suministro de agua y de gas natural por ductos al consumidor final
# Year
# 1993                                          20449750000
# 1994                                          23762000000
# 1995                                          33723750000
# 1996                                          47497000000
# 1997                                          59150000000
#
#                                                                               \
# Sector Industrias manufactureras Información en medios masivos       Minería
# Year
# 1993                339313000000                   24247250000   95249000000
# 1994                368239000000                   29100500000   98542250000
# 1995                516595000000                   33240250000  145586250000
# 1996                729511500000                   43152250000  186202750000
# 1997                926912750000                   51156500000  243776750000
#
#                                                             \
# Sector Otros servicios excepto actividades gubernamentales
# Year
# 1993                                          47910000000
# 1994                                          53213000000
# 1995                                          62088000000
# 1996                                          76762250000
# 1997                                          95897750000
#
#                                                                                   \
# Sector Servicios de alojamiento temporal y de preparación de alimentos y bebidas
# Year
# 1993                                          60417750000
# 1994                                          68732500000
# 1995                                          74639250000
# 1996                                          95240250000
# 1997                                         123957000000
#
#                                                                                            \
# Sector Servicios de apoyo a los negocios y manejo de residuos, y servicios de remediación
# Year
# 1993                                          53051250000
# 1994                                          65023250000
# 1995                                          84520000000
# 1996                                         115744500000
# 1997                                         147046250000
#
#                                                                                           \
# Sector Servicios de esparcimiento culturales y deportivos, y otros servicios recreativos
# Year
# 1993                                          11986250000
# 1994                                          13898500000
# 1995                                          15278500000
# 1996                                          18273000000
# 1997                                          24072500000
#
#                                                                        \
# Sector Servicios de salud y de asistencia social Servicios educativos
# Year
# 1993                                 30217250000          51212750000
# 1994                                 34293000000          61798250000
# 1995                                 42063000000          74717500000
# 1996                                 50907750000          95301000000
# 1997                                 62537000000         121768500000
#
#                                            \
# Sector Servicios financieros y de seguros
# Year
# 1993                          64778000000
# 1994                          68247500000
# 1995                          83002000000
# 1996                          71349750000
# 1997                          71721000000
#
#                                                                               \
# Sector Servicios inmobiliarios y de alquiler de bienes muebles e intangibles
# Year
# 1993                                         186926750000
# 1994                                         216424500000
# 1995                                         291693750000
# 1996                                         374871000000
# 1997                                         457040500000
#
#                                                         \
# Sector Servicios profesionales, científicos y técnicos
# Year
# 1993                                       20651000000
# 1994                                       24503750000
# 1995                                       31172000000
# 1996                                       43906500000
# 1997                                       59214250000
#
#
# Sector Transportes, correos y almacenamiento
# Year
# 1993                             89392750000
# 1994                            100598250000
# 1995                            138120750000
# 1996                            195435500000
# 1997                            257772250000
